# %%
# Setup
import matplotlib.pyplot as plt  # for generating plots
import matplotlib
import pandas as pd     # import the pandas library to read a .csv file
import numpy as np      # use py for numpy from now on
# this command tells Jupyter Notebook to plot in this space
# %matplotlib inline

median_home_values = pd.read_csv("Median_List_raw_month.csv")   # make sure the data file is in the same directory

MeanByMonth = median_home_values.mean(axis=0)  # calculate the mean of each column
MedianByMonth = median_home_values.median(axis=0)
# Out:
# /var/folders/tn/9wq1twg57s148hqf15cf4hgr0000gn/T/ipykernel_4537/556122850.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   MeanByMonth = median_home_values.mean(axis=0)  # calculate the mean of each column
# /var/folders/tn/9wq1twg57s148hqf15cf4hgr0000gn/T/ipykernel_4537/556122850.py:12: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   MedianByMonth = median_home_values.median(axis=0)

# %%
#Example 1
plt.plot(MeanByMonth)   # generates the plot
plt.show()              # prints the plot here

# %%
#Example 2
labels = ['12/2017','6/2018','12/2018','6/2019','1/2020']  # the new x tick marks
x = np.arange(0,35,7)                       # the label locations
fig,ax = plt.subplots()
ax.set_xticks(x)
ax.set_xticklabels(labels)                  # all of the above was for the fancy x tick labels
plt.plot(MeanByMonth)
plt.title('Median Housing Cost by Month')    # title
plt.xlabel('Month')                          # xlabel
plt.ylabel('Cost in dollars')                # ylabel
plt.show()                                   # must be last item

# %%
#Example 3
fig,ax = plt.subplots()             # New for multi line graphs set up parameters

labels = ['12/2017','6/2018','12/2018','6/2019','1/2020']  # the new x tick marks
x = np.arange(0,35,7)                       # the label locations
ax.set_xticks(x)
ax.set_xticklabels(labels)                  # all of the above was for the fancy x tick labels

# new for multi line graphs
ax.plot(MeanByMonth)
ax.plot(MedianByMonth)

ax.set_title('Median Purchase Cost of Housing in 35 US Regions')
ax.legend(['Mean','Median'])
plt.ylabel('Cost in dollars')                # ylabel

plt.show()

# %%
#Example 4
MeanByMonth.plot.bar()
plt.title('Median Housing Cost by Month')    # title
plt.xlabel('Month')                          # xlabel
plt.ylabel('Cost in dollars')                # ylabel
# Out:
# Text(0, 0.5, 'Cost in dollars')

# %% [markdown]
# Question 1: Which of these, line graph (using on the median line) or the bar chart is easier to read? There are times when you would use either one - when you’re trying to focus on a specific idea - Why would you use a line graph for this data? Why would you use a bar chart for this data?
#
# The line graph was easier to read because it is easier for the viewer to spot a trend over a 6 month period, rather than a much more condensed month to month change as we saw in the bar chart. As stated in the Visualization document, "graphs are used to display relationships among multiple quantitative values by giving them shape". We see a much more fluid shape with a graph because the changes are much more continuous, whereas a bar chart appears more "clunky". A bar chart would be useful for this data if the trends were being shown over a longer period of time. The median housing cost would have more impact on the viewer if we were viewing a year to year change.

# %%
#Example 5
import math
low = min(MeanByMonth)
high = max(MeanByMonth)
MeanByMonth.plot.bar()
plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
plt.xlabel('Month')
plt.ylabel('Cost in Dollars')
# Out:
# Text(0, 0.5, 'Cost in Dollars')

# %%
#Setup
df = pd.read_csv('temporal.csv')   # read in the data to df

df.head(10)   # first 10 data rows
# Out:
#          Mes  data science  machine learning  deep learning  categorical  \
# 0   1/1/2004            12                18              4            1
# 1   2/1/2004            12                21              2            1
# 2   3/1/2004             9                21              2            1
# 3   4/1/2004            10                16              4            1
# 4   5/1/2004             7                14              3            1
# 5   6/1/2004             9                17              3            1
# 6   7/1/2004             9                16              3            1
# 7   8/1/2004             7                14              3            1
# 8   9/1/2004            10                17              4            1
# 9  10/1/2004             8                17              4            1
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %%
#Example 6
df.describe ()  # see how the data is distributed - maxs, mins, means
# Out:
#        data science  machine learning  deep learning  categorical  Unnamed: 5
# count    194.000000        194.000000     194.000000   194.000000         0.0
# mean      20.953608         27.396907      24.231959     0.257732         NaN
# std       23.951006         28.091490      34.476887     0.438517         NaN
# min        4.000000          7.000000       1.000000     0.000000         NaN
# 25%        6.000000          9.000000       2.000000     0.000000         NaN
# 50%        8.000000         13.000000       3.000000     0.000000         NaN
# 75%       26.750000         31.500000      34.000000     1.000000         NaN
# max      100.000000        100.000000     100.000000     1.000000         NaN

# %%
#Example 7
plt.plot(df['Mes'], df['data science'], label='data science')  # Parameter label is to
    # indicate the legend, but it doesn't show here.  More later

# %%
#Example 8
format_dict = {'data science':'${0:,.2f}', 'Mes':'{:%m-%Y}', 'machine learning':'{:.2%}'}
#We make sure that the Month column has datetime format
df['Mes'] = pd.to_datetime(df['Mes'])     # only display years, not months
#We apply the style to the visualization
df.head().style.format(format_dict)

plt.plot(df['Mes'], df['data science'], label='data science')
plt.plot(df['Mes'], df['machine learning'], label='machine learning')
plt.plot(df['Mes'], df['deep learning'], label='deep learning')

# %% [markdown]
# Question 2: What happened? What can you determine from this? Be fairly specific.
#
# From the graph we can infer that there was an interest or popularity spike beginning in 2014 in Data Science, Machine Learning, and Deep Learning. The problem is that this is an "assumption" because there aren't label indicators telling us that this is the specific relationship.

# %%
#Example 9
format_dict = {'data science':'${0:,.2f}', 'Mes':'{:%m-%Y}', 'machine learning':'{:.2%}'}
#We make sure that the Month column has datetime format
df['Mes'] = pd.to_datetime(df['Mes'])     # only display years, not months
#We apply the style to the visualization
df.head().style.format(format_dict)

plt.plot(df['Mes'], df['data science'], label='data science')
plt.plot(df['Mes'], df['machine learning'], label='machine learning')
plt.plot(df['Mes'], df['deep learning'], label='deep learning')
plt.xlabel('Date')
plt.ylabel('Popularity')
plt.title('Popularity of AI terms by date')
plt.grid(True)
plt.legend()

# %% [markdown]
# Question 3: Update your answers from Q2 with this better graph.
#
# Now that we have axis labels, a title, and a color coded legend, you can gather that in 2014 we are seeing a growth in interest in these terms.

# %%
#Example 10
fig, axes = plt.subplots(2,2)                     # my output will be a 2x2 figure (4 graphs)
axes[0, 0].hist(df['data science'])               # our first histogram!
axes[0, 1].scatter(df['Mes'], df['data science'])  # our first scatterplot
axes[1, 0].plot(df['Mes'], df['machine learning'])
axes[1, 1].plot(df['Mes'], df['deep learning'])

# %%
#Example 11
plt.scatter(df['data science'], df['machine learning'])
plt.xlabel('frequency of data science')
plt.ylabel('frequency of machine learning')
plt.title('Searches for data science vs machine learning')
plt.grid(True)

# %%
#Example 12
MeanByMonth = df.mean(axis=0)  # calculate the mean of each column
StdByMonth = df.std(axis=0)    # calculate the std of each column

data=[['data science', 20.95,23.95],['machine learning',27.4,28.1],['deep learning',24.2,34.5]]

dfErrorBar = pd.DataFrame(data,columns=['Category','mean','std'])

dfErrorBar
# Out:
# /var/folders/tn/9wq1twg57s148hqf15cf4hgr0000gn/T/ipykernel_4537/2856457299.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   MeanByMonth = df.mean(axis=0)  # calculate the mean of each column
#            Category   mean    std
# 0      data science  20.95  23.95
# 1  machine learning  27.40  28.10
# 2     deep learning  24.20  34.50

# %%
#Example 13
plt.errorbar(dfErrorBar['Category'],dfErrorBar['mean'],yerr=dfErrorBar['std'], fmt = 'o',
             color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)
plt.title('Error Bar of Searches')
plt.grid(True)

# %% [markdown]
# Exercise 1: Remembering that the housing data is the average cost of housing over time for 119 cities, generate a line graph with average costs with NYC and Philadephia on it. Make sure it has correct/pretty labels for both x and y axis, and an appropriate title.

# %%
# Setup
import matplotlib.pyplot as plt  # for generating plots
import matplotlib
import pandas as pd     # import the pandas library to read a .csv file
import numpy as np      # use py for numpy from now on
# this command tells Jupyter Notebook to plot in this space
# %matplotlib inline

df = pd.read_csv('Median_List_raw_month.csv')   # read in the data to df

dft = df.drop('StateName', axis=1).set_index('RegionName').T.reset_index()
dft.rename(columns={'index':'months'}, inplace=True)

fig,ax = plt.subplots()

labels = ['12/2017', '6/2018', '12/2018', '6/2019', '1/2020']
x = np.arange(0,35,7)
ax.set_xticks(x)
ax.set_xticklabels(labels)
plt.plot(dft['New York, NY'])
plt.plot(dft['Philadelphia, PA'])
ax.set_title('Cost of Homes in NYC and Philadelphia')
ax.legend(['NYC', 'Philadelphia'])

plt.ylabel('Cost')
plt.show()

# %% [markdown]
# Exercise 2: Using the same housing data, generate a 2x2 figure (subplot) with Houston city data (line 7, but remember numbering starts at 0, so you’ll use 6) and San Antonio data (line 27). Logically organize a line plot for each, a histogram (for both) and a scatter plot with Houston on the x-axis.

# %%
df = pd.read_csv("Median_List_raw_month.csv")

dftt = df.drop('StateName', axis=1).set_index('RegionName').T.reset_index()
dftt.rename(columns={'index': 'months'}, inplace=True)

fig, axes = plt.subplots(2,2)
axes[0,0].plot(dftt['Houston, TX'])
axes[0,1].plot(dftt['San Antonio, TX'])
axes[1,0].scatter(dftt['Houston, TX'], dftt['months'])
axes[1,1].hist(dftt['Houston, TX'], dftt['San Antonio, TX'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 10>()
#       8 axes[0,1].plot(dftt['San Antonio, TX'])
#       9 axes[1,0].scatter(dftt['Houston, TX'], dftt['months'])
# ---> 10 axes[1,1].hist(dftt['Houston, TX'], dftt['San Antonio, TX'])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6639, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6635 # Loop through datasets
#    6636 for i in range(nx):
#    6637     # this will automatically overwrite bins,
#    6638     # so that each histogram uses the same bins
# -> 6639     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6640     tops.append(m)
#    6641 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File <__array_function__ internals>:5, in histogram(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/histograms.py:793, in histogram(a, bins, range, normed, weights, density)
#     681 r"""
#     682 Compute the histogram of a dataset.
#     683
#    (...)
#     789
#     790 """
#     791 a, weights = _ravel_and_check_weights(a, weights)
# --> 793 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     795 # Histogram is an integer or a float array depending on the weights.
#     796 if weights is None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/histograms.py:431, in _get_bin_edges(a, bins, range, weights)
#     429     bin_edges = np.asarray(bins)
#     430     if np.any(bin_edges[:-1] > bin_edges[1:]):
# --> 431         raise ValueError(
#     432             '`bins` must increase monotonically, when an array')
#     434 else:
#     435     raise ValueError('`bins` must be 1d, when an array')
#
# ValueError: `bins` must increase monotonically, when an array
