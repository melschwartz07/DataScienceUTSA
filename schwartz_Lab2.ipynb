# %%
import matplotlib.pyplot as plt  # for generating plots
import matplotlib
import pandas as pd     # import the pandas library to read a .csv file
import numpy as np      # use py for numpy from now on
# this command tells Jupyter Notebook to plot in this space
# %matplotlib inline

df = pd.read_csv('Schwartz-Melanie-female.csv')   # read in the data to df

plt.hist(df['Wake-up time           (24 -hour time)'], bins=15)
plt.xlabel('Wake Time')
plt.ylabel('Days')
plt.title('Frequency of Wake Up Times')
plt.grid(True)

# %%
import matplotlib.pyplot as plt  # for generating plots
import matplotlib
import pandas as pd     # import the pandas library to read a .csv file
import numpy as np      # use py for numpy from now on
# this command tells Jupyter Notebook to plot in this space
# %matplotlib inline

df = pd.read_csv('Schwartz-Melanie-female.csv')   # read in the data to df

plt.hist(df['Bed-time       (24-hour time)'], bins=15)
plt.xlabel('Bed Time')
plt.ylabel('Days')
plt.title('Frequency of Bed Times')
plt.grid(True)

# %%
import matplotlib.pyplot as plt  # for generating plots
import matplotlib
import pandas as pd     # import the pandas library to read a .csv file
import numpy as np      # use py for numpy from now on

# %matplotlib inline

df = pd.read_csv('Schwartz-Melanie-female.csv')   # read in the data to df
df['time_asleep'] = df['Wake-up time           (24 -hour time)'] - df['Bed-time       (24-hour time)']

print('Time asleep: ')
print(df)
# Out:
# Time asleep:
#    Wake-up Date  Day caffeine?    (1 = Yes, 0 = No)  \
# 0     8/25/2022                                   1
# 1     8/26/2022                                   1
# 2     8/27/2022                                   1
# 3     8/28/2022                                   1
# 4     8/29/2022                                   1
# 5     8/30/2022                                   1
# 6     8/31/2022                                   1
# 7      9/1/2022                                   1
# 8      9/2/2022                                   1
# 9      9/3/2022                                   1
# 10     9/4/2022                                   1
# 11     9/5/2022                                   1
# 12     9/6/2022                                   1
# 13     9/7/2022                                   1
# 14     9/8/2022                                   1
# 15     9/9/2022                                   1
# 16    9/10/2022                                   1
# 17    9/11/2022                                   1
# 18    9/12/2022                                   1
# 19    9/13/2022                                   1
# 20    9/14/2022                                   1
#
#     Night caffeine?  (1 = Yes, 0 = No)  Minutes of day napping  \
# 0                                    0                       0
# 1                                    1                       0
# 2                                    0                       0
# 3                                    0                       0
# 4                                    0                       0
# 5                                    0                       0
# 6                                    0                      60
# 7                                    1                       0
# 8                                    0                       0
# 9                                    0                      25
# 10                                   0                       0
# 11                                   0                       0
# 12                                   1                       0
# 13                                   1                       0
# 14                                   0                       0
# 15                                   0                       0
# 16                                   0                       0
# 17                                   0                       0
# 18                                   0                       0
# 19                                   0                       0
# 20                                   0                       0
#
#     Minutes to fall asleep  Bed-time       (24-hour time)  \
# 0                       15                          -2.50
# 1                       15                          -2.00
# 2                       10                          -1.00
# 3                       10                          -1.00
# 4                       10                           0.00
# 5                       10                          -0.25
# 6                       10                          -1.00
# 7                       10                          -0.75
# 8                       15                          -1.50
# 9                       25                           0.00
# 10                      15                          -1.00
# 11                      10                          -1.50
# 12                      15                          -2.00
# 13                      20                          -1.25
# 14                      20                          -1.25
# 15                      25                          -1.00
# 16                      20                           0.00
# 17                      15                          -0.50
# 18                      20                          -1.00
# 19                      15                          -1.25
# 20                      15                          -1.50
#
#     Wake-up time           (24 -hour time)  \
# 0                                     7.50
# 1                                     7.50
# 2                                     9.00
# 3                                     8.50
# 4                                     7.50
# 5                                     7.50
# 6                                     7.50
# 7                                     7.50
# 8                                     7.50
# 9                                     9.25
# 10                                    9.50
# 11                                    7.50
# 12                                    7.50
# 13                                    7.50
# 14                                    7.50
# 15                                    7.50
# 16                                   10.25
# 17                                   10.00
# 18                                    7.50
# 19                                    7.50
# 20                                    7.50
#
#     Alarm?               (1 = Yes, 0 = No)  minutes awakened during night  \
# 0                                        1                             20
# 1                                        1                              0
# 2                                        0                              0
# 3                                        0                              0
# 4                                        1                              0
# 5                                        1                             10
# 6                                        1                              0
# 7                                        1                              0
# 8                                        1                             10
# 9                                        1                             10
# 10                                       1                              0
# 11                                       1                              0
# 12                                       1                             15
# 13                                       1                              0
# 14                                       1                              0
# 15                                       1                              0
# 16                                       1                             15
# 17                                       1                              0
# 18                                       1                              0
# 19                                       1                              0
# 20                                       1                             10
#
#     SSI  time_asleep
# 0     2        10.00
# 1     2         9.50
# 2     2        10.00
# 3     2         9.50
# 4     2         7.50
# 5     2         7.75
# 6     2         8.50
# 7     2         8.25
# 8     2         9.00
# 9     2         9.25
# 10    2        10.50
# 11    2         9.00
# 12    2         9.50
# 13    2         8.75
# 14    1         8.75
# 15    1         8.50
# 16    1        10.25
# 17    2        10.50
# 18    2         8.50
# 19    2         8.75
# 20    2         9.00

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Schwartz-Melanie-female.csv')

# Let's make sure 'date' is actually a date in pandas
data["Wake-up Date"] = pd.to_datetime(data["Wake-up Date"])

date = data["Wake-up Date"]
value = data["time_asleep"]

fig, ax = plt.subplots(figsize=(10, 8))
ax.plot(date, value);
plt.title('Hours of Sleep Each Night')    # title
plt.xlabel('Wake Up Day')                          # xlabel
plt.ylabel('Hours')                # ylabel
# Out:
# Text(0, 0.5, 'Hours')

# %%
import matplotli b.pyplot as plt  # for generating plots
import matplotlib
import pandas as pd     # import the pandas library to read a .csv file
import numpy as np      # use py for numpy from now on
# this command tells Jupyter Notebook to plot in this space
# %matplotlib inline

df = pd.read_csv("Schwartz-Melanie-female.csv")

plt.scatter(df['Wake-up Date'], df['Wake-up time           (24 -hour time)'])
plt.xlabel('Wake up Date')
plt.ylabel('Wake up Time')
plt.title('Wake Up Times By the Day')
plt.grid(True)

# %%
import matplotlib.pyplot as plt  # for generating plots
import matplotlib
import pandas as pd     # import the pandas library to read a .csv file
import numpy as np      # use py for numpy from now on
# this command tells Jupyter Notebook to plot in this space
# %matplotlib inline

df = pd.read_csv("Schwartz-Melanie-female.csv")

plt.scatter(df['Wake-up Date'], df['Bed-time       (24-hour time)'])
plt.xlabel('Wake up Date')
plt.ylabel('Bed Time')
plt.title('Bed Times By the Day')
plt.grid(True)

# %%
import matplotlib.pyplot as plt  # for generating plots
import matplotlib
import pandas as pd     # import the pandas library to read a .csv file
import numpy as np      # use py for numpy from now on
# this command tells Jupyter Notebook to plot in this space
# %matplotlib inline

df = pd.read_csv("Schwartz-Melanie-female.csv")

plt.scatter(df['Wake-up Date'], df['SSI'])
plt.xlabel('Wake up Date')
plt.ylabel('SSI')
plt.title('SSI By the Day')
plt.grid(True)
