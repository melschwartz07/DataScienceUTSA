# %%
# Setup
import seaborn as sns     # sns is the standard alias for seaborn
import matplotlib.pyplot as plt

# %%
# Seaborn data sets
import bs4   # bs4 (Beautiful Soup) is a Python library for pulling data out of HTML and XML files
print(sns.__version__)

print(sns.get_dataset_names())
# Out:
# 0.11.2
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
# Setup
tips=sns.load_dataset('tips')  # load the dataset
print(type(tips))
print(tips.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Exercise 1: Load and do the same to penguins.

penguins=sns.load_dataset('penguins')
print(type(penguins))
print(penguins.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# Example 1
sns.relplot(x='total_bill', y='tip', data=tips)
plt.title("Total Bill vs Tips Given")
plt.show()

# %%
#Exercise 2: Generate a scatter plot with the penguin data, with body mass as independent
# variable and flipper length as the dependent variable.

sns.relplot(x='body_mass_g', y='flipper_length_mm', data=penguins)
plt.title("Body Mass(g) vs Flipper Length(mm)")
plt.show()

# %%
# Example 2
sns.relplot(x='total_bill', y='tip', data=tips,kind='line', hue='sex', aspect=2)
plt.title("Total Bill vs Tips Given by gender")
plt.show()

# %%
#Exercise 3: Generate the same graph for the penguins, based on the species.

sns.relplot(x='body_mass_g', y='flipper_length_mm', data=penguins, kind='line', hue='species',aspect=3)
plt.title("Body Mass(g) vs Flipper Length(mm)")
plt.show()

# %%
# Example 3
from collections import Counter
Counter(tips.sex).most_common(2)
# Out:
# [('Male', 157), ('Female', 87)]

# %%
#Exercise 4: How many penguins are there in each species listed?
from collections import Counter
Counter(penguins.species).most_common(3)
# Out:
# [('Adelie', 152), ('Gentoo', 124), ('Chinstrap', 68)]

# %%
# Example 4
sns.regplot(x='total_bill', y='tip', data=tips)
plt.title("Total Bill vs Tips Given with Best fit line")
# Out:
# Text(0.5, 1.0, 'Total Bill vs Tips Given with Best fit line')

# %%
#Exercise 5: Draw a best-fit line for mass and flipper length.
sns.regplot(x='body_mass_g', y='flipper_length_mm', data=penguins)
plt.title("Body Mass(g) vs Flipper Length(mm)")
plt.show()

# %%
# Example 5
sns.catplot(x='day', y='tip',data=tips)
plt.title("Tips by Day of the Week")
# Out:
# Text(0.5, 1.0, 'Tips by Day of the Week')

# %%
#Exercise 6: Plot the mass of the penguins dataset based on species.

sns.catplot(x='species', y='body_mass_g', data=penguins)
plt.title("Penguins by Species and Their Weight")
# Out:
# Text(0.5, 1.0, 'Penguins by Species and Their Weight')

# %%
# Example 6
sns.catplot(x='day', y='tip',data=tips,kind='swarm')
plt.title("Tips by Day of the Week")
# Out:
# /Users/melanieschwartz/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Tips by Day of the Week')

# %%
#Exercise 7: Repeat for the penguins.
sns.catplot(x='species', y='body_mass_g',data=penguins,kind='swarm')
plt.title("Penguins Species by Weight")
# Out:
# Text(0.5, 1.0, 'Penguins Species by Weight')

# %%
# Example 7
sns.catplot(x='day', y='tip',data=tips,kind='bar', hue='sex',order=['Thur','Sat','Sun'])
plt.title("Tips by Day of the Week by Gender")
# Out:
# Text(0.5, 1.0, 'Tips by Day of the Week by Gender')

# %%
#Exercise 8: Generate the same graph, by penguin species.

sns.catplot(x='species', y='body_mass_g',data=penguins,kind='bar', hue='sex',order=['Adelie','Chinstrap','Gentoo'])
plt.title("Mass of Species by Gender")
# Out:
# Text(0.5, 1.0, 'Mass of Species by Gender')

# %%
# Example 8
sns.catplot(x='day', y='tip',data=tips,kind='box', hue='sex',order=['Thur','Sat','Sun'])
plt.title("Tips by Day of the Week by Gender")
# Out:
# Text(0.5, 1.0, 'Tips by Day of the Week by Gender')

# %%
#Exercise 9: Do the same for the penguins. What did you learn from this when compared to the error bar chart?
sns.catplot(x='species', y='body_mass_g',data=penguins,kind='box', hue='sex',order=['Adelie','Chinstrap','Gentoo'])
plt.title("Mass of Species by Gender")
# Out:
# Text(0.5, 1.0, 'Mass of Species by Gender')

# %%
# Example 9
sns.distplot(a=tips.total_bill, bins=20)
plt.title("Distribution of Total Bill")
# Out:
# /Users/melanieschwartz/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Total Bill')

# %%
#Exercise 10: What is the distribution of the penguin mass? Discuss what you see.

# %%
# Example 10
sns.relplot(x='total_bill', y='tip', data=tips, hue='sex', aspect=2)
plt.title("Total Bill vs Tips Given by gender")
# Out:
# Text(0.5, 1.0, 'Total Bill vs Tips Given by gender')

# %%
# Data Exploration
mpg=sns.load_dataset('mpg')  # load the dataset
mpg.info
# Out:
# <bound method DataFrame.info of       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# Example 11
sns.catplot(x='model_year', y='displacement',data=mpg,kind='box',hue='origin')
plt.title("Engine displacement in cars by country of origin")
# Out:
# Text(0.5, 1.0, 'Engine displacement in cars by country of origin')

# %%
# Example 12
sns.violinplot(x='model_year', y='displacement',data=mpg,kind='box',hue='origin')
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='displacement'>

# %%
# Example 13
import pandas as pd    # must have pandas for this

usa_mpg = mpg[mpg['origin'].isin(['usa'])]   # just find those with 'usa' in the origin field

sns.catplot(x='model_year', y='displacement',data=usa_mpg,kind='box')
plt.title("Engine displacement in cars by model year")
# Out:
# Text(0.5, 1.0, 'Engine displacement in cars by model year')

# %%
# Better violin plot
sns.violinplot(x='model_year', y='displacement',data=usa_mpg,kind='box')
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='displacement'>

# %%
# Example 14
sns.pairplot(mpg)

# %%
# Example 14 - more colors
sns.pairplot(mpg,hue='origin')

# %%
#Exercise 11: Load the titanic data. Plot boxplot and violin plots looking at the age and gender, based on their ‘class’ onboard the Titanic. Also do a pairplot on this data, broken out by gender, and another broken out by survival.
titanic=sns.load_dataset('titanic')

sns.catplot(x='class', y='age',data=titanic,kind='box', hue='sex',order=['First','Second','Third'])
plt.title("Age and Gender by Class")
# Out:
# Text(0.5, 1.0, 'Age and Gender by Class')

# %%
sns.violinplot(x='class', y='age',data=titanic,kind='box',hue='sex')
plt.title("Age and Gender by Class")
# Out:
# Text(0.5, 1.0, 'Age and Gender by Class')

# %%
variable=titanic[['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive']]
sns.pairplot(variable,hue='sex')

# %%
sns.pairplot(variable,hue='survived')
